# %% [markdown]
# # Basic Metrics
#
# When we think about summarizing data, what are the metrics that we look at?
#
# In this notebook, we will look in the price of weed dataset along with the demographic information of the United States.
#
# To read how the data was acquired, please read [this](https://github.com/amitkaps/weed/blob/master/1-Acquire.ipynb) to get more information
#
# This notebook will make use of pandas quite a bit.

# %%
import numpy as np
import pandas as pd
from datetime import datetime as dt
from scipy import stats

# %% [markdown]
# ### Read the input datasets. There are three datasets:
#
# 1. Weed price by date / state
# 2. Demographics of State
# 3. Population of state

# %%
prices_pd = pd.read_csv("../data/Weed_Price.csv", parse_dates=[-1])
demography_pd = pd.read_csv("../data/Demographics_State.csv")
population_pd = pd.read_csv("../data/Population_State.csv")

# %%
prices_pd.head()
# Out:
#         State   HighQ  HighQN    MedQ  MedQN    LowQ  LowQN       date
# 0     Alabama  339.06    1042  198.64    933  149.49    123 2014-01-01
# 1      Alaska  288.75     252  260.60    297  388.58     26 2014-01-01
# 2     Arizona  303.31    1941  209.35   1625  189.45    222 2014-01-01
# 3    Arkansas  361.85     576  185.62    544  125.87    112 2014-01-01
# 4  California  248.78   12096  193.56  12812  192.92    778 2014-01-01

# %%
prices_pd.tail()
# Out:
#                State   HighQ  HighQN    MedQ  MedQN  LowQ  LowQN       date
# 22894       Virginia  364.98    3513  293.12   3079   NaN    284 2014-12-31
# 22895     Washington  233.05    3337  189.92   3562   NaN    160 2014-12-31
# 22896  West Virginia  359.35     551  224.03    545   NaN     60 2014-12-31
# 22897      Wisconsin  350.52    2244  272.71   2221   NaN    167 2014-12-31
# 22898        Wyoming  322.27     131  351.86    197   NaN     12 2014-12-31

# %%
demography_pd.head()
# Out:
#        region  total_population  percent_white  percent_black  percent_asian  \
# 0     alabama           4799277             67             26              1
# 1      alaska            720316             63              3              5
# 2     arizona           6479703             57              4              3
# 3    arkansas           2933369             74             15              1
# 4  california          37659181             40              6             13
#
#    percent_hispanic  per_capita_income  median_rent  median_age
# 0                 4              23680          501        38.1
# 1                 6              32651          978        33.6
# 2                30              25358          747        36.3
# 3                 7              22170          480        37.5
# 4                38              29527         1119        35.4

# %%
population_pd.head()
# Out:
#        region     value
# 0     alabama   4777326
# 1      alaska    711139
# 2     arizona   6410979
# 3    arkansas   2916372
# 4  california  37325068

# %%
prices_pd.dtypes
# Out:
# State             object
# HighQ            float64
# HighQN             int64
# MedQ             float64
# MedQN              int64
# LowQ             float64
# LowQN              int64
# date      datetime64[ns]
# dtype: object

# %%
#this works
prices_pd.sort_values('State', ascending=False)
# Out:
#          State   HighQ  HighQN    MedQ  MedQN    LowQ  LowQN       date
# 22898  Wyoming  322.27     131  351.86    197     NaN     12 2014-12-31
# 2753   Wyoming  351.78     110  360.09    160  161.30     12 2014-07-04
# 13157  Wyoming  354.11      95  378.34    140  161.30     11 2014-02-18
# 458    Wyoming  312.84     147  317.38    226     NaN     13 2015-06-01
# 19532  Wyoming  320.39     133  350.57    202     NaN     12 2015-01-27
# 2090   Wyoming  330.41     117  356.25    170     NaN     12 2014-09-03
# 9740   Wyoming  351.78     110  359.34    162  161.30     12 2014-07-13
# 8210   Wyoming  351.78     110  359.34    162  161.30     12 2014-07-11
# 6119   Wyoming  354.03      94  378.95    134  161.30     11 2014-01-09
# 13106  Wyoming  320.39     133  351.58    199     NaN     12 2015-01-18
# 13055  Wyoming  354.03      94  377.77    136  161.30     11 2014-01-18
# 19583  Wyoming  351.81      96  378.46    144  161.30     11 2014-02-27
# 22133  Wyoming  330.41     117  356.25    170     NaN     12 2014-08-30
# 19634  Wyoming  353.67     101  374.73    147  161.30     11 2014-03-27
# 2039   Wyoming  349.69     116  349.90    166  161.30     12 2014-08-03
# 6170   Wyoming  320.39     133  351.58    199     NaN     12 2015-01-09
# 13004  Wyoming  323.53     128  350.78    191     NaN     12 2014-12-17
# 6068   Wyoming  326.84     126  353.26    188     NaN     12 2014-12-08
# 19481  Wyoming  354.03      94  378.64    137  161.30     11 2014-01-27
# 2141   Wyoming  328.51     119  355.77    172     NaN     12 2014-10-03
# 22184  Wyoming  328.51     119  354.94    171     NaN     12 2014-09-30
# 5915   Wyoming  328.54     118  356.25    170     NaN     12 2014-09-08
# 13412  Wyoming  351.25     109  359.79    158  161.30     12 2014-06-18
# 8261   Wyoming  349.69     116  349.90    167  161.30     12 2014-08-11
# 13361  Wyoming  314.89     146  345.46    222     NaN     13 2015-05-18
# 19328  Wyoming  331.66     120  354.21    177     NaN     12 2014-10-26
# 5966   Wyoming  328.51     119  355.77    173     NaN     12 2014-10-08
# 19379  Wyoming  326.89     125  354.20    184     NaN     12 2014-11-26
# 13208  Wyoming  355.71     100  376.85    146  161.30     11 2014-03-18
# 2192   Wyoming  326.51     122  353.86    178     NaN     12 2014-11-03
# ...        ...     ...     ...     ...    ...     ...    ...        ...
# 7548   Alabama  339.42    1467  204.52   1362     NaN    174 2014-11-10
# 20655  Alabama  340.60    1402  204.64   1271     NaN    161 2014-08-28
# 10812  Alabama  336.40    1561  209.23   1488     NaN    185 2015-01-15
# 7344   Alabama  340.62    1349  203.91   1205  147.74    156 2014-07-10
# 11169  Alabama  341.02    1319  204.59   1182  148.39    152 2014-06-15
# 1632   Alabama  335.86    1584  209.64   1529     NaN    194 2015-02-03
# 1785   Alabama  340.84    1258  205.10   1123  143.76    144 2014-05-03
# 19890  Alabama  340.60    1402  204.64   1271     NaN    161 2014-08-27
# 11526  Alabama  340.10    1069  198.74    962  153.19    127 2014-01-16
# 7140   Alabama  341.12    1270  205.16   1142  142.88    145 2014-05-10
# 19941  Alabama  339.81    1425  204.13   1302     NaN    162 2014-09-27
# 11475  Alabama  339.12    1516  207.02   1429     NaN    181 2014-12-15
# 1836   Alabama  340.63    1304  204.38   1174  144.23    149 2014-06-03
# 19992  Alabama  338.61    1446  204.44   1335     NaN    169 2014-10-27
# 11424  Alabama  339.13    1471  205.12   1371     NaN    177 2014-11-15
# 7191   Alabama  338.58    1755  207.65   1712     NaN    209 2015-05-10
# 20043  Alabama  339.62    1487  205.61   1397     NaN    178 2014-11-27
# 11373  Alabama  338.86    1436  204.34   1327     NaN    165 2014-10-15
# 20247  Alabama  335.70    1579  209.13   1520     NaN    193 2015-01-28
# 20094  Alabama  339.65    1033  198.04    926  147.15    122 2013-12-27
# 11322  Alabama  340.40    1413  203.73   1293     NaN    161 2014-09-15
# 7242   Alabama  340.75    1312  204.22   1180  146.12    151 2014-06-10
# 1734   Alabama  341.20    1213  204.50   1086  145.88    141 2014-04-03
# 20145  Alabama  338.81    1530  207.83   1450     NaN    182 2014-12-27
# 11271  Alabama  340.53    1395  204.01   1259  145.79    160 2014-08-15
# 7293   Alabama  337.32    1889  206.09   1807     NaN    218 2015-06-10
# 20196  Alabama  338.68    1086  199.74    977  152.02    129 2014-01-28
# 1683   Alabama  340.20    1146  202.86   1038  147.52    134 2014-03-03
# 11220  Alabama  340.88    1358  203.66   1213  147.74    156 2014-07-15
# 0      Alabama  339.06    1042  198.64    933  149.49    123 2014-01-01
#
# [22899 rows x 8 columns]

# %%
prices_pd.sort_values('date')
# Out:
#                 State   HighQ  HighQN    MedQ  MedQN    LowQ  LowQN       date
# 20119      New Mexico  294.88     557  216.55    434   63.70     42 2013-12-27
# 20123            Ohio  336.70    3039  211.49   2793  168.72    398 2013-12-27
# 20124        Oklahoma  362.53     748  227.27    660  119.61    128 2013-12-27
# 20125          Oregon  213.54    1606  188.36   1329  175.87     61 2013-12-27
# 20126        Maryland  380.08    1954  248.50   1534  197.82    150 2013-12-27
# 20127   Massachusetts  355.03    2867  297.05   2455  218.37    218 2013-12-27
# 20128        Michigan  299.31    3035  277.59   2517  227.25    229 2013-12-27
# 20129       Minnesota  370.92    1703  280.47   1525  179.36    100 2013-12-27
# 20130     Mississippi  339.66     407  150.44    349  138.66     93 2013-12-27
# 20131        Missouri  370.73    1555  241.34   1280  154.15    203 2013-12-27
# 20132    Pennsylvania  372.80    3801  266.31   3179  192.00    361 2013-12-27
# 20133    Rhode Island  331.72     527  262.74    359  207.93     33 2013-12-27
# 20134  South Carolina  350.18    1145  202.02    895  176.93    119 2013-12-27
# 20135    South Dakota  387.80     161  363.80    165  125.68     20 2013-12-27
# 20136       Tennessee  359.22    1536  223.78   1215  201.64    145 2013-12-27
# 20137           Texas  343.41    5966  235.86   5598  141.59    844 2013-12-27
# 20138            Utah  291.94     683  233.54    659  169.84     42 2013-12-27
# 20139         Vermont  379.88     277  323.31    224  187.06     24 2013-12-27
# 20140        Virginia  374.23    2452  288.59   1940  220.69    200 2013-12-27
# 20141      Washington  236.28    2336  191.86   2327  148.33    108 2013-12-27
# 20142   West Virginia  360.98     349  197.75    367  158.25     40 2013-12-27
# 20143       Wisconsin  357.56    1614  267.14   1353  228.19    124 2013-12-27
# 20122    North Dakota  415.70     134  361.62    198  269.55     13 2013-12-27
# 20121  North Carolina  355.84    2759  247.60   1896  157.16    224 2013-12-27
# 20120        New York  351.98    5773  268.83   5786  190.31    479 2013-12-27
# 20118      New Jersey  355.03    2233  294.16   2788  226.61    184 2013-12-27
# 20096         Arizona  303.52    1934  209.19   1619  189.45    222 2013-12-27
# 20097        Arkansas  361.78     575  184.90    543  125.87    112 2013-12-27
# 20098      California  248.77   12021  193.44  12724  193.88    770 2013-12-27
# 20099        Colorado  236.19    2138  195.56   1685  237.04    123 2013-12-27
# ...               ...     ...     ...     ...    ...     ...    ...        ...
# 8109          Alabama  337.32    1889  206.09   1807     NaN    218 2015-06-11
# 8159          Wyoming  313.72     148  317.38    226     NaN     13 2015-06-11
# 8129          Montana  264.57     787  238.30    446     NaN     36 2015-06-11
# 8130         Nebraska  330.29     789  239.64    859     NaN     78 2015-06-11
# 8131           Nevada  266.35    1434  223.94   1653     NaN     89 2015-06-11
# 8132    New Hampshire  349.72     664  285.17    758     NaN     58 2015-06-11
# 8154          Vermont  364.83     408  304.70    434     NaN     32 2015-06-11
# 8153             Utah  285.11    1080  232.95   1230     NaN     71 2015-06-11
# 8152            Texas  326.15    9587  232.49  10264     NaN   1287 2015-06-11
# 8151        Tennessee  345.15    2595  227.12   2301     NaN    260 2015-06-11
# 8150     South Dakota  358.46     254  340.24    303     NaN     29 2015-06-11
# 8149   South Carolina  333.82    2001  208.65   1690     NaN    188 2015-06-11
# 8148     Rhode Island  313.51     806  248.94    683     NaN     47 2015-06-11
# 8147     Pennsylvania  358.23    6206  268.26   5908     NaN    562 2015-06-11
# 8146         Missouri  347.57    2554  248.27   2500     NaN    334 2015-06-11
# 8145      Mississippi  331.03     797  157.17    746     NaN    176 2015-06-11
# 8156       Washington  231.63    3781  187.35   4145     NaN    183 2015-06-11
# 8144        Minnesota  340.02    2699  269.68   2990     NaN    149 2015-06-11
# 8142    Massachusetts  339.50    4499  280.51   4461     NaN    324 2015-06-11
# 8141         Maryland  359.33    3271  265.44   2942     NaN    215 2015-06-11
# 8140           Oregon  202.10    2533  178.18   2406     NaN    113 2015-06-11
# 8139         Oklahoma  348.62    1298  241.65   1282     NaN    215 2015-06-11
# 8138             Ohio  331.03    4894  219.22   5086     NaN    619 2015-06-11
# 8137     North Dakota  383.80     250  338.38    401     NaN     27 2015-06-11
# 8136   North Carolina  341.84    4754  244.14   3625     NaN    357 2015-06-11
# 8135         New York  338.37    8902  261.17  10170     NaN    683 2015-06-11
# 8134       New Mexico  282.77     904  217.46    775     NaN     73 2015-06-11
# 8133       New Jersey  342.49    3450  283.30   4943     NaN    287 2015-06-11
# 8143         Michigan  282.34    4493  263.09   4318     NaN    329 2015-06-11
# 8157    West Virginia  357.52     638  224.12    649     NaN     65 2015-06-11
#
# [22899 rows x 8 columns]

# %%
#but this doesn't
#prices_pd.sort_index('State', 'date')

# error says there is no axis named date! ? but in the cell above it works... so 
#it's a problem with how I am string the arguments...

#prices_pd.sort_values('State','date', ascending=False)
prices_pd.sort_values('date', ascending=False)
# Out:
#                       State   HighQ  HighQN    MedQ  MedQN    LowQ  LowQN  \
# 8159                Wyoming  313.72     148  317.38    226     NaN     13
# 8134             New Mexico  282.77     904  217.46    775     NaN     73
# 8132          New Hampshire  349.72     664  285.17    758     NaN     58
# 8131                 Nevada  266.35    1434  223.94   1653     NaN     89
# 8130               Nebraska  330.29     789  239.64    859     NaN     78
# 8129                Montana  264.57     787  238.30    446     NaN     36
# 8128                  Maine  304.57     701  232.84    772     NaN     73
# 8127              Louisiana  357.86    1861  240.69   1672     NaN    369
# 8126               Kentucky  341.12    1708  184.61   1771     NaN    201
# 8125                 Kansas  345.99    1298  260.93   1201     NaN    155
# 8124                   Iowa  361.66    1102  287.66   1225     NaN    136
# 8123                Indiana  328.38    2755  217.96   2646     NaN    362
# 8121                  Idaho  273.38     510  241.60    797     NaN     42
# 8120                 Hawaii  302.22     539  259.02    620     NaN     32
# 8119                Georgia  317.03    5223  216.63   4205     NaN    346
# 8118                Florida  297.04   10815  215.90   9703     NaN    782
# 8117   District of Columbia  345.77     764  281.96    729     NaN     54
# 8116               Delaware  353.64     566  241.95    506     NaN     47
# 8115            Connecticut  332.37    2118  264.92   2514     NaN    146
# 8114               Colorado  241.18    3598  194.83   3431     NaN    215
# 8113             California  241.93   18492  187.89  22027     NaN   1232
# 8112               Arkansas  333.88     993  211.88    992     NaN    171
# 8111                Arizona  296.70    2992  208.37   2872     NaN    344
# 8110                 Alaska  293.43     406  265.52    576     NaN     41
# 8109                Alabama  337.32    1889  206.09   1807     NaN    218
# 8133             New Jersey  342.49    3450  283.30   4943     NaN    287
# 8122               Illinois  348.91    6384  279.46   6530     NaN    509
# 8135               New York  338.37    8902  261.17  10170     NaN    683
# 8147           Pennsylvania  358.23    6206  268.26   5908     NaN    562
# 8136         North Carolina  341.84    4754  244.14   3625     NaN    357
# ...                     ...     ...     ...     ...    ...     ...    ...
# 20095                Alaska  288.75     252  260.82    296  388.58     26
# 20094               Alabama  339.65    1033  198.04    926  147.15    122
# 20117         New Hampshire  366.06     420  289.81    440  561.05     38
# 20116                Nevada  269.97     896  219.10    920  233.47     60
# 20143             Wisconsin  357.56    1614  267.14   1353  228.19    124
# 20118            New Jersey  355.03    2233  294.16   2788  226.61    184
# 20132          Pennsylvania  372.80    3801  266.31   3179  192.00    361
# 20142         West Virginia  360.98     349  197.75    367  158.25     40
# 20141            Washington  236.28    2336  191.86   2327  148.33    108
# 20140              Virginia  374.23    2452  288.59   1940  220.69    200
# 20139               Vermont  379.88     277  323.31    224  187.06     24
# 20138                  Utah  291.94     683  233.54    659  169.84     42
# 20137                 Texas  343.41    5966  235.86   5598  141.59    844
# 20136             Tennessee  359.22    1536  223.78   1215  201.64    145
# 20135          South Dakota  387.80     161  363.80    165  125.68     20
# 20134        South Carolina  350.18    1145  202.02    895  176.93    119
# 20133          Rhode Island  331.72     527  262.74    359  207.93     33
# 20131              Missouri  370.73    1555  241.34   1280  154.15    203
# 20120              New York  351.98    5773  268.83   5786  190.31    479
# 20130           Mississippi  339.66     407  150.44    349  138.66     93
# 20129             Minnesota  370.92    1703  280.47   1525  179.36    100
# 20128              Michigan  299.31    3035  277.59   2517  227.25    229
# 20127         Massachusetts  355.03    2867  297.05   2455  218.37    218
# 20126              Maryland  380.08    1954  248.50   1534  197.82    150
# 20125                Oregon  213.54    1606  188.36   1329  175.87     61
# 20124              Oklahoma  362.53     748  227.27    660  119.61    128
# 20123                  Ohio  336.70    3039  211.49   2793  168.72    398
# 20122          North Dakota  415.70     134  361.62    198  269.55     13
# 20121        North Carolina  355.84    2759  247.60   1896  157.16    224
# 20119            New Mexico  294.88     557  216.55    434   63.70     42
#
#             date
# 8159  2015-06-11
# 8134  2015-06-11
# 8132  2015-06-11
# 8131  2015-06-11
# 8130  2015-06-11
# 8129  2015-06-11
# 8128  2015-06-11
# 8127  2015-06-11
# 8126  2015-06-11
# 8125  2015-06-11
# 8124  2015-06-11
# 8123  2015-06-11
# 8121  2015-06-11
# 8120  2015-06-11
# 8119  2015-06-11
# 8118  2015-06-11
# 8117  2015-06-11
# 8116  2015-06-11
# 8115  2015-06-11
# 8114  2015-06-11
# 8113  2015-06-11
# 8112  2015-06-11
# 8111  2015-06-11
# 8110  2015-06-11
# 8109  2015-06-11
# 8133  2015-06-11
# 8122  2015-06-11
# 8135  2015-06-11
# 8147  2015-06-11
# 8136  2015-06-11
# ...          ...
# 20095 2013-12-27
# 20094 2013-12-27
# 20117 2013-12-27
# 20116 2013-12-27
# 20143 2013-12-27
# 20118 2013-12-27
# 20132 2013-12-27
# 20142 2013-12-27
# 20141 2013-12-27
# 20140 2013-12-27
# 20139 2013-12-27
# 20138 2013-12-27
# 20137 2013-12-27
# 20136 2013-12-27
# 20135 2013-12-27
# 20134 2013-12-27
# 20133 2013-12-27
# 20131 2013-12-27
# 20120 2013-12-27
# 20130 2013-12-27
# 20129 2013-12-27
# 20128 2013-12-27
# 20127 2013-12-27
# 20126 2013-12-27
# 20125 2013-12-27
# 20124 2013-12-27
# 20123 2013-12-27
# 20122 2013-12-27
# 20121 2013-12-27
# 20119 2013-12-27
#
# [22899 rows x 8 columns]

# %% [markdown]
# #### Sort the data on state and date, then fill NA values

# %%
prices_pd.sort_values=['State', 'date'], inplace=True)
prices_pd.fillna(method='ffill', inplace=True)
# Out:
#   File "<ipython-input-9-e7e40198ccd0>", line 1
#     prices_pd.sort_values=['State', 'date'], inplace=True)
#                                                          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Finding mean, median, mode, variance, standard deviation for California

# %% [markdown]
# #### Mean
#
# arithmetic average of a range of values or quantities, computed by dividing the total of all values by the number of values.

# %%
california_pd = prices_pd[prices_pd.State == "California"].copy(True)
california_pd.head()
# Out:
#             State   HighQ  HighQN    MedQ  MedQN    LowQ  LowQN       date
# 20098  California  248.77   12021  193.44  12724  193.88    770 2013-12-27
# 20863  California  248.74   12025  193.44  12728  193.88    770 2013-12-28
# 21577  California  248.76   12047  193.55  12760  193.60    772 2013-12-29
# 22291  California  248.82   12065  193.54  12779  193.80    773 2013-12-30
# 22801  California  248.76   12082  193.54  12792  193.80    773 2013-12-31

# %%
ca_sum = california_pd['HighQ'].sum()

# %%
ca_count = california_pd['HighQ'].count()

# %%
ca_mean = ca_sum / ca_count
print "Mean weed price in CA is:", ca_mean
# Out:
# Mean weed price in CA is: 245.376124722

# %% [markdown]
# #### Exercise: Find CA mean for 2013, 2014 & 2015 separately
#
# *Hint:* `california_pd.iloc[0]['date'].year`

# %% [markdown]
# #### Median
#
# Denotes value or quantity lying at the midpoint of a frequency distribution of observed values or quantities, such that there is an equal probability of falling above or below it. Simply put, it is the *middle* value in the list of numbers.

# %%
ca_count
# Out:
# 449

# %% [markdown]
# If count is odd, the median is the value at (n+1)/2,
#
# else it is the average of n/2 and (n+1)/2

# %%
ca_highq_pd = california_pd.sort(columns=['HighQ'])
ca_highq_pd.head()

# %%
ca_median = ca_highq_pd.HighQ.iloc[(ca_count) / 2]
print "Median price of weed in CA is:", ca_median
# Out:
# Median price of weed in CA is: 245.31

# %% [markdown]
# #### Mode
#
# It is the number which appears most often in a set of numbers.

# %%
ca_mode = ca_highq_pd.HighQ.value_counts().index[0]
print "The most common price is CA, as indicated by its mode, is:", ca_mode
# Out:
# The most common price is CA, as indicated by its mode, is: 245.05

# %% [markdown]
# #### Variance
#
# > Once two statistician of height 4 feet and 5 feet have to cross a river of AVERAGE depth 3 feet. Meanwhile, a third person comes and said, "what are you waiting for? You can easily cross the river"
#
# It's the average distance of the data values from the *mean*
#
# <img style="float: left;" src="img/variance.png" height="320" width="320">

# %%
california_pd['HighQ_dev'] = (california_pd['HighQ'] - ca_mean) ** 2

# %%
ca_HighQ_variance = california_pd.HighQ_dev.sum() / (ca_count - 1)
print "Variance of High Quality weed prices in CA is:", ca_HighQ_variance
# Out:
# Variance of High Quality weed prices in CA is: 2.98268628798

# %% [markdown]
# #### Standard Deviation
#
# It is the square root of variance. This will have the same units as the data and mean.

# %%
ca_HighQ_SD = np.sqrt(ca_HighQ_variance)
print "Standard Deviation of High Quality weed prices in CA is:", ca_HighQ_SD
# Out:
# Standard Deviation of High Quality weed prices in CA is: 1.72704553732

# %% [markdown]
# #### Using Pandas built-in function

# %%
california_pd.describe()
# Out:
#             HighQ        HighQN        MedQ         MedQN        LowQ  \
# count  449.000000    449.000000  449.000000    449.000000  449.000000
# mean   245.376125  14947.073497  191.268909  16769.821826  189.783586
# std      1.727046   1656.133565    1.524028   2433.943191    1.598252
# min    241.840000  12021.000000  187.850000  12724.000000  187.830000
# 25%    244.480000  13610.000000  190.260000  14826.000000  188.600000
# 50%    245.310000  15037.000000  191.570000  16793.000000  188.600000
# 75%    246.220000  16090.000000  192.550000  18435.000000  191.320000
# max    248.820000  18492.000000  193.630000  22027.000000  193.880000
#
#              LowQN   HighQ_dev
# count   449.000000  449.000000
# mean    976.298441    2.976043
# std     120.246714    3.961134
# min     770.000000    0.000015
# 25%     878.000000    0.106357
# 50%     982.000000    0.729103
# 75%    1060.000000    4.435761
# max    1232.000000   12.504178

# %%
california_pd.HighQ.mode()
# Out:
# 0    245.03
# 1    245.05
# dtype: float64

# %% [markdown]
# #### Co-variance
#
# covariance as a measure of the (average) co-variation between two variables, say x and y. Covariance describes both how far the variables are spread out, and the nature of their relationship, Covariance is a measure of how much two variables change together. Compare this to Variance, which is just the range over which one measure (or variable) varies.
#
# <img style="float: left;" src="img/covariance.png" height="270" width="270">
#
# <br>
# <br>
# <br>
# <br>
#
# #### Co-variance of weed price in California vs New York

# %%
ny_pd = prices_pd[prices_pd['State'] == 'New York'].copy(True)
ny_pd.head()
# Out:
#           State   HighQ  HighQN    MedQ  MedQN    LowQ  LowQN       date
# 20120  New York  351.98    5773  268.83   5786  190.31    479 2013-12-27
# 20885  New York  351.92    5775  268.83   5786  190.31    479 2013-12-28
# 21599  New York  351.99    5785  269.02   5806  190.75    480 2013-12-29
# 22313  New York  352.02    5791  268.98   5814  190.75    480 2013-12-30
# 22823  New York  351.97    5794  268.93   5818  190.75    480 2013-12-31

# %%
ny_pd = ny_pd.ix[:,[1,7]]
ny_pd.columns = ['NY_HighQ', 'date']

# %%
ny_pd.head()
# Out:
#        NY_HighQ       date
# 20120    351.98 2013-12-27
# 20885    351.92 2013-12-28
# 21599    351.99 2013-12-29
# 22313    352.02 2013-12-30
# 22823    351.97 2013-12-31

# %%
ca_ny_pd = pd.merge(california_pd.ix[:,[1,7]].copy(), ny_pd, on="date")
ca_ny_pd.rename(columns={"HighQ": "CA_HighQ"}, inplace=True)
ca_ny_pd.head()
# Out:
#    CA_HighQ       date  NY_HighQ
# 0    248.77 2013-12-27    351.98
# 1    248.74 2013-12-28    351.92
# 2    248.76 2013-12-29    351.99
# 3    248.82 2013-12-30    352.02
# 4    248.76 2013-12-31    351.97

# %%
ny_mean = ca_ny_pd.NY_HighQ.mean()
ny_mean
# Out:
# 346.9127616926502

# %%
ca_ny_pd['ca_dev'] = ca_ny_pd['CA_HighQ'] - ca_mean
ca_ny_pd.head()
# Out:
#    CA_HighQ       date  NY_HighQ    ca_dev
# 0    248.77 2013-12-27    351.98  3.393875
# 1    248.74 2013-12-28    351.92  3.363875
# 2    248.76 2013-12-29    351.99  3.383875
# 3    248.82 2013-12-30    352.02  3.443875
# 4    248.76 2013-12-31    351.97  3.383875

# %%
ca_ny_pd['ny_dev'] = ca_ny_pd['NY_HighQ'] - ny_mean
ca_ny_pd.head()
# Out:
#    CA_HighQ       date  NY_HighQ    ca_dev    ny_dev
# 0    248.77 2013-12-27    351.98  3.393875  5.067238
# 1    248.74 2013-12-28    351.92  3.363875  5.007238
# 2    248.76 2013-12-29    351.99  3.383875  5.077238
# 3    248.82 2013-12-30    352.02  3.443875  5.107238
# 4    248.76 2013-12-31    351.97  3.383875  5.057238

# %%
ca_ny_cov = (ca_ny_pd['ca_dev'] * ca_ny_pd['ny_dev']).sum() / (ca_count - 1)
print "Covariance of the High Quality weed prices in CA and NY is:", ca_ny_cov
# Out:
# Covariance of the High Quality weed prices in CA and NY is: 5.91681496729

# %% [markdown]
# #### Using Pandas built-in function

# %%
ca_ny_pd.cov()
# Out:
#           CA_HighQ   NY_HighQ    ca_dev     ny_dev
# CA_HighQ  2.982686   5.916815  2.982686   5.916815
# NY_HighQ  5.916815  12.245147  5.916815  12.245147
# ca_dev    2.982686   5.916815  2.982686   5.916815
# ny_dev    5.916815  12.245147  5.916815  12.245147

# %% [markdown]
# ### Correlation
#
# Extent to which two or more variables fluctuate together. A positive correlation indicates the extent to which those variables increase or decrease in parallel; a negative correlation indicates the extent to which one variable increases as the other decreases.
#
# <img style="float: left;" src="img/correlation.gif" height="270" width="270">
#
# <br>
# <br>
# <br>
#
# #### Finding correlation between weed prices in New York and California

# %%
ca_highq_std = ca_ny_pd.CA_HighQ.std()
ny_highq_std = ca_ny_pd.NY_HighQ.std()

ca_ny_corr = ca_ny_cov / (ca_highq_std * ny_highq_std)
print "Correlation between weed prices in NY and CA:", ca_ny_corr
# Out:
# Correlation between weed prices in NY and CA: 0.979043961106

# %%
ca_ny_pd.corr()
# Out:
#           CA_HighQ  NY_HighQ    ca_dev    ny_dev
# CA_HighQ  1.000000  0.979044  1.000000  0.979044
# NY_HighQ  0.979044  1.000000  0.979044  1.000000
# ca_dev    1.000000  0.979044  1.000000  0.979044
# ny_dev    0.979044  1.000000  0.979044  1.000000

# %% [markdown]
# # Correlation != Causation
#
# correlation between two variables does not necessarily imply that one causes the other.
#
#
# <img style="float: left;" src="img/correlation_not_causation.gif" height="570" width="570">
